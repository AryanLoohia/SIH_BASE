# %%
import numpy as np
from collections import Counter
import math

def hex_to_bytes(hex_str):
    """Convert hexadecimal string to bytes."""
    return bytes.fromhex(hex_str)

def calculate_entropy(data):
    """Calculate the entropy of a given data."""
    if not data:
        return 0
    entropy = 0
    data_len = len(data)
    counter = Counter(data)
    for count in counter.values():
        probability = count / data_len
        entropy -= probability * math.log2(probability)
    return entropy

def top_n_frequencies(data, n=5):
    """Calculate the top-N frequencies of characters in the data."""
    freq_dist = Counter(data)
    most_common = freq_dist.most_common(n)
    return {f'top_{i+1}_freq': count for i, (char, count) in enumerate(most_common)}

def extract_features(ciphertext_hex, features):
    """Extract features from the given ciphertext in hexadecimal form."""
    # Convert hex to bytes
    ciphertext_bytes = hex_to_bytes(ciphertext_hex)

    # Ciphertext length
    features['length'] = len(ciphertext_bytes)

    # Entropy
    features['entropy'] = calculate_entropy(ciphertext_bytes)

    # Frequency distribution
    freq_dist = top_n_frequencies(ciphertext_bytes)
    features.update({f'freq_{byte}': count for byte, count in freq_dist.items()})

    # Block size (assuming common block sizes)
    block_sizes = [8, 16, 32]
    for block_size in block_sizes:
        if len(ciphertext_bytes) % block_size == 0:
            features['block_size'] = block_size
            break
    else:
        features['block_size'] = None

    # Feature 3: Byte Distribution
    byte_distribution = Counter(ciphertext_bytes)
    features['byte_distribution_mean'] = np.mean(list(byte_distribution.values()))
    features['byte_distribution_std'] = np.std(list(byte_distribution.values()))

    # Feature 4: Repetition Patterns
    repetition_count = sum([ciphertext_bytes[i] == ciphertext_bytes[i+1] for i in range(len(ciphertext_bytes) - 1)])
    features['repetition_count'] = repetition_count / len(ciphertext_bytes)

    # Feature 5: Hamming Distance Between Adjacent Blocks
    block_size = features['block_size']  # Assuming AES-like block size
    if (features['block_size'] == None):
        hamming_distances = []
    else:
        hamming_distances = []
        for i in range(0, len(ciphertext_bytes) - block_size, block_size):
            block1 = ciphertext_bytes[i:i+block_size]
            block2 = ciphertext_bytes[i+block_size:i+2*block_size]
            hamming_distances.append(np.sum(np.bitwise_xor(list(block1), np.array(list(block2)))))
    features['avg_hamming_distance'] = np.mean(hamming_distances) if hamming_distances else 0

    # Feature 7: Bit-Level Features
    bits = ''.join(format(byte, '08b') for byte in ciphertext_bytes)
    features['bit_zeros_ratio'] = bits.count('0') / len(bits)
    features['bit_ones_ratio'] = bits.count('1') / len(bits)

    # Feature 8: Padding Detection
    padding_byte = ciphertext_bytes[-1]
    padding_length = padding_byte if all(byte == padding_byte for byte in ciphertext_bytes[-padding_byte:]) else 0
    features['padding_length'] = padding_length

    return features

def extract_iv_and_infer_mode(ciphertext_hex, features, block_size=16):
    """Extract IV and infer mode of operation from the given ciphertext in hexadecimal form."""
    # Convert hex to bytes
    ciphertext_bytes = hex_to_bytes(ciphertext_hex)

    # Extract IV (assuming it's the first block)
    iv = ciphertext_bytes[:block_size]
    features['iv'] = iv

    # Infer mode of operation (basic heuristics)
    if len(ciphertext_bytes) % block_size != 0:
        features['mode'] = 'Unknown or Stream Cipher'
    else:
        # Check for ECB patterns (repeated blocks)
        blocks = [ciphertext_bytes[i:i+block_size] for i in range(0, len(ciphertext_bytes), block_size)]
        if len(blocks) != len(set(blocks)):
            features['mode'] = 'ECB'
        else:
            features['mode'] = 'CBC or other block mode'

    return features

def save_features_to_excel(features, filename='features.xlsx'):
    """Convert features dictionary to DataFrame and save as Excel file."""
    # Convert dictionary to DataFrame
    df = pd.DataFrame([features])

    # Save DataFrame to Excel file
    df.to_excel(filename, index=False)
    print(f"Features saved to {filename}")

# %%
import pandas as pd
df = pd.DataFrame(pd.read_excel('ECC_New_Dataset.xlsx'))
df.head()
# Out:
#                                        Original Text  Length  \
# 0  \nOnce upon a time, in a dense forest, there l...     136
# 1  .\nHe didn't want to harm his friend, but he a...     152
# 2  e home with me today?"\n\nThe monkey was thril...     145
# 3         was more cautious about whom he trusted.\n      41
# 4   day, a crocodile swam up to the bank of the r...     143
#
#                              Encrypted Data (Binary)  \
# 0  b'\xe81\x93\x8f\x85p\x90,\xe8\xaf\xe7\xb0/\x06...
# 1  b'&d\x9c\x955H7\x86\xb9#\xff6w$98\x90\x1c\x82\...
# 2  b'\xe2\x05,\x9d\xb7QH\xec\xd4\xd6\xc1\xe0@\xc4...
# 3  b'\x04\xa4\x1b\x82\xb4\xf5\xa9\x9c%\x0eL\x97/\...
# 4  b'\xe89AS\xf8\x9b{\x7f\xf0ft1\xf4\xf2\x0b(\xdb...
#
#                                 Encrypted Data (Hex)  \
# 0  e831938f8570902ce8afe7b02f063e42be2891e0d3cd92...
# 1  26649c9535483786b923ff3677243938901c8298f9ddca...
# 2  e2052c9db75148ecd4d6c1e040c419051e25fa88d55ad5...
# 3  04a41b82b4f5a99c250e4c972ff2da0a0d0620ca030f1f...
# 4  e8394153f89b7b7ff0667431f4f20b28db01ec9751440d...
#
#                                                Curve  \
# 0  <cryptography.hazmat.primitives.asymmetric.ec....
# 1  <cryptography.hazmat.primitives.asymmetric.ec....
# 2  <cryptography.hazmat.primitives.asymmetric.ec....
# 3  <cryptography.hazmat.primitives.asymmetric.ec....
# 4  <cryptography.hazmat.primitives.asymmetric.ec....
#
#                                                 Mode                    Info  \
# 0  <class 'cryptography.hazmat.primitives.ciphers...      b'encryption data'
# 1  <class 'cryptography.hazmat.primitives.ciphers...  b'authentication data'
# 2  <class 'cryptography.hazmat.primitives.ciphers...  b'authentication data'
# 3  <class 'cryptography.hazmat.primitives.ciphers...       b'handshake data'
# 4  <class 'cryptography.hazmat.primitives.ciphers...  b'authentication data'
#
#                                  Intilisation_Vector Algorithm
# 0  b'\xd0\r\x1c\xafd\x9a}\xd1\x08\xb4O\xba\xb7m\x...       ECC
# 1  b'\x0f\xda\xc4\xc21\x80\x7fO@\xa0\xab\x08\xad\...       ECC
# 2  b'\xad\xcf\xef\x0e=\x12\x1aL\n\xf85\xc6\x9eY\x...       ECC
# 3  b'B\x95\xdd_B\xfdU\xf7yI\x8d\xca\xcb\xba\xbc\x80'       ECC
# 4    b'\xdf*$\xb9\xcc/\x00\x84A\xd7j\t\xa9d\x04\x15'       ECC

# %%
features_dataset = []

for i in range(0, len(df)):
    features = {}
    features['Original Text'] = df['Original Text'][i]
    features['Length'] = df['Length'][i]
    features['Encrypted Data (Binary)'] = df['Encrypted Data (Binary)'][i]
    features['Encrypted Data (Hex)'] = df['Encrypted Data (Hex)'][i]
    features['Algorithm'] = df['Algorithm'][i]
    j = df['Encrypted Data (Hex)'][i]
    features = extract_features(j, features=features)
    features = extract_iv_and_infer_mode(j, features=features)
    print(features)
    features_dataset.append(features)
# Out:
# {'Original Text': '\nOnce upon a time, in a dense forest, there lived a monkey on a large mango tree.\nThe tree was on the bank of a river, providing the mon', 'Length': 136, 'Encrypted Data (Binary)': "b'\\xe81\\x93\\x8f\\x85p\\x90,\\xe8\\xaf\\xe7\\xb0/\\x06>B\\xbe(\\x91\\xe0\\xd3\\xcd\\x92\\xe1>i\\n\\x08]\\x92\\x18\\xb4a\\xec\\xd5\\xc9\\x13\\xeb\\xd3Y\\xfb\\xd4-3\\x82\\xdf\\x84\\xcb\\xe7\\\\\\xa5\\xd1\\xf1\\x1d\\x19%\\x8b-\\xed\\x8a\\xfc\\x14@\\xf4\\xe1\\xc4\\x00\\x16\\x94\\x1a\\x8b?#\\xddHa\\xa4\\x92\\x9b\\t\\x90s\\xd1\\xd5v\\x18\\xa1\\x8c\\xce\\xb9\\x96\\x8e\\xab\\x89\\xe7g\\x81\\xd2\\x01\\xbc\\x17\\x9fi.uIV\\xce\\xedaC\\x92\\n\\x02\\xe7\\x82\\x88\\x8b4\\x88{j<R-#\\x18l\\xe0\\x19\\\\\\xc42He^'", 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 136, 'entropy': 6.5505543853043475, 'freq_top_1_freq': 4, 'freq_top_2_freq': 4, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': 8, 'byte_distribution_mean': 1.3203883495145632, 'byte_distribution_std': 0.641805587613142, 'repetition_count': 0.0, 'avg_hamming_distance': 1059.125, 'bit_zeros_ratio': 0.5303308823529411, 'bit_ones_ratio': 0.4696691176470588, 'padding_length': 0, 'iv': b'\xe81\x93\x8f\x85p\x90,\xe8\xaf\xe7\xb0/\x06>B', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': ".\nHe didn't want to harm his friend, but he also couldn't ignore his wife's wishes.\nReluctantly, he agreed to bring the monkey to her.\n\nThe next day, th", 'Length': 152, 'Encrypted Data (Binary)': 'b\'&d\\x9c\\x955H7\\x86\\xb9#\\xff6w$98\\x90\\x1c\\x82\\x98\\xf9\\xdd\\xca\\xf7Qt\\xbef\\xd2\\xca\\x1bst"\\x8fx\\x05\\x9a\\xe0\\xac`\\x03\\n\\x17\\x1dl\\xa6[\\xe5`\\x0e\\xd90\\xbdG@\\xc6\\xf4\\x17:2{\\xc0D<t\\x1cD\\xa6\\x02\\xb2d]=\\x009\\xa4\\xc18\\x06\\x0f$\\x01\\xe6\\xe8\\xa1\\xf4\\xb4X\\xd5\\xea\\xb8m\\xb5\\xb7\\xcb\\x8f\\x07\\x9a\\xbcM}+\\xd7-\\\'\\x9c` \\x10\\t\\xee:%L\\xbe=\\xe8\\xa0M\\xf0\\x9c{\\x9ayS\\x97$\\xcc\\x94sXEj\\xf1\\x129h\\x85\\xbd6\\xf64\\xbcX&\\xd04\\xe5\\xf8\\x92@\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length':
 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'tandard) fall under this category. The simplicity of symmetric encryption often leads to its usage in high-speed data transmissions, where per', 'Length': 142, 'Encrypted Data (Binary)': 'b\'\\xc6BD\\xc8\\x1c\\xa1\\xb5\\xc4\\x15\\x12\\xec\\x88fC)/\\xf3\\\'g\\xdf<)CS\\xe7\\xc4\\x07\\xf4*\\x08\\xb8R\\xcaH\\xd9\\x9c\\xc7Gy\\x02\\xc9X\\x9aW\\xaf\\x93\\x17\\xd8p\\x9a\\xb3\\x07\\x19tS\\xb3|\\xd9\\xe8\\xdf\\xce\\xb0\\x99\\x052\\xea\\xcdQc\\xfb*\\x93\\x8e6nZ\\xa4:\\xe1\\xb6""r\\xad\\xa6\\xa1\\x90\\xeeP)\\x02]\\xb6\\xd7\\xe1\\x8a\\x9c\\xc9\\xfar\\xed\\x18P\\x97\\x9a\\xd3w\\xcb\\xf8\\x18\\x13\\t\\x97+E\\xb5\\x95\\x95\\xc2M0\\x85H\\xd9\\xf1\\xc1=&k,;H\\xfc?\\xd1\\xbb\\xedg\\xf1D\\x05\\x10\'', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 142, 'entropy': 6.649609443387402, 'freq_top_1_freq': 3, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 2, 'block_size': None, 'byte_distribution_mean': 1.3148148148148149, 'byte_distribution_std': 0.5383126612499494, 'repetition_count': 0.014084507042253521, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.5132042253521126, 'bit_ones_ratio': 0.4867957746478873, 'padding_length': 0, 'iv': b'\xc6BD\xc8\x1c\xa1\xb5\xc4\x15\x12\xec\x88fC)/', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'r encryption and a private key for decryption. RSA and ECC (Elliptic Curve Cryptography) are examples of asymmetric algorithms. While asymmetr', 'Length': 142, 'Encrypted Data (Binary)': "b'\\xe2J\\x17\\xdf0\\xeb\\x1e\\r\\x0c\\x1d\\x11\\xc8\\x9b\\x1fB\\xfd\\xa0Z \\\\O\\x87\\x85\\xba\\x8e-n\\xb5\\x83d`\\xc2|\\xc5P\\x14\\x1b,\\xc6\\xa6\\xffT%i\\xb8Yx4\\xb0\\xe2\\xfakJ\\x12W-H\\x9aH\\x93\\xa8\\x18\\xbak~9(\\xf3\\xa4\\xe7\\x9b\\x01\\x94\\xb9\\xb2\\xec\\xe1\\xb7\\x18\\x83`\\n\\xdcY5\\xba\\x16eX8mcZ[\\xa6\\x14CS\\x1d\\xa3\\xf34%\\xcdP\\\\\\x18CC=\\xb4\\xa6 \\xa34\\x83\\xabT\\xb3\\x9b\\x169\\xfd\\xb5\\xe0\\x90{c\\xe6\\x1a\\x081 \\xbdx\\xfbPB4\\xe2\\xb3\\xf8'", 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 142, 'entropy': 6.482183827114041, 'freq_top_1_freq': 4, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': None, 'byte_distribution_mean': 1.4343434343434343, 'byte_distribution_std': 0.698651170334973, 'repetition_count': 0.007042253521126761, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.5272887323943662, 'bit_ones_ratio': 0.4727112676056338, 'padding_length': 0, 'iv': b'\xe2J\x17\xdf0\xeb\x1e\r\x0c\x1d\x11\xc8\x9b\x1fB\xfd', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 's, ciphertext plays a central role. The transaction data is encrypted, and the zero-knowledge proof ensures that the conditions of the transactio', 'Length': 145, 'Encrypted Data (Binary)': 'b"\\x94\\x08Nn\\xda\\xdb\\xae0\\xf2\\xc1L\\x00\\xab\\tU(\\xee\\x00\\x0b\\xb9\\xbe\\xe4\\x89\\x84\\x9f\\x0c\\x14^\\x18\\x93\\xed\\x83w\\xcc)\\x88\\xb3\\x0b4\\x07@\\xd5\\x80\\x95\\xbfAm\\xc8\\xdf\\xfd\\x87\\xfbM\\xf9\\x10k\\xe0\\x8e\\x94\\x9d$\\xeei-6{\\x85\\xfb\\xc3l\\x03X/\\xb0bC\\xa7P\'\\x04\\xcf\\x12nY\\x1d\\x1eR\\xd3\\xac\\xec\\xc3\\xc2\\xe4\\x93\\x96Q\\x14|i.u6\\xda\\x92K\\xfa\\xc3\\n\\xf9\\xbc4\\xbf\\xdd\\x91\\x9feV]\\x02o\\x95fp`5\\xb8\\xa0Yz\\xbe\\xfb\\xd0q@\\x8c/\\xa0\\xd6\\xf5C\\x9e\\xec_\\x8e2"', 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 145, 'entropy': 6.783289952054074, 'freq_top_1_freq': 3, 'freq_top_2_freq': 3, 'freq_top_3_freq': 2, 'freq_top_4_freq': 2, 'freq_top_5_freq': 2, 'block_size': None, 'byte_distribution_mean': 1.2393162393162394, 'byte_distribution_std': 0.4650075387601861, 'repetition_count': 0.0, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.5086206896551724, 'bit_ones_ratio': 0.49137931034482757, 'padding_length': 0, 'iv': b'\x94\x08Nn\xda\xdb\xae0\xf2\xc1L\x00\xab\tU(', 'mode': 'Unknown or Stream Cipher'}
# {'Original Text': 'eates a transaction and signs it with her private key. The transaction data is then broadcast to the Bitcoin network. The network nodes', 'Length': 135, 'Encrypted Data (Binary)': "b'\\xfe\\x03\\x12\\r\\x84\\x8a@\\x88\\xdc\\x1e$V\\xab\\xcf\\xb5\\xfa\\xc8\\x06g\\xc2S\\xe5.\\x05\\xb2\\x0c\\x80\\x8f\\x9c\\xb4\\x8e\\xa6\\x01J\\xe2nx\\x94\\x9a\\xeb\\xe4\\x1e\\xe7%\\xde\\xbdtB\\xd0\\xa0\\x9f\\x11\\x07P\\xae\\xb3\\x962i\\xa2\\xc8\\xdf\\xe5\\xa2~\\x18\\xa8\\xcbdVd\\x91\\x86\\xc7\\x7fE\\xeb z\\xb8\\t|k\\xc9.\\x99\\xa4_F\\xc9Xu\\x85\\xef\\xff\\x1e\\xce:\\x03F\\x92\\xfc(\\n|^p\\x06\\xc1\\x9b\\xa6\\x04\\xe3t\\xe7\\x84\\x83\\xac\\xb5t\\x9f\\x06\\xa4\\x9a\\xc4\\xf2\\x13\\xe8\\r\\xac\\xa4Yg\\xa6\\xa3'", 'Encrypted Data (Hex)': '', 'Algorithm': 'ECC', 'length': 135, 'entropy': 6.619227171044793, 'freq_top_1_freq': 3, 'freq_top_2_freq': 3, 'freq_top_3_freq': 3, 'freq_top_4_freq': 3, 'freq_top_5_freq': 3, 'block_size': None, 'byte_distribution_mean': 1.2735849056603774, 'byte_distribution_std': 0.5413647824680593, 'repetition_count': 0.0, 'avg_hamming_distance': 0, 'bit_zeros_ratio': 0.5203703703703704, 'bit_ones_ratio': 0.47962962962962963, 'padding_length': 0, 'iv': b'\xfe\x03\x12\r\x84\x8a@\x88\xdc\x1e$V\xab\xcf\xb5\xfa', 'mode': 'Unknown or Stream Cipher'}

# %%
df = pd.DataFrame(features_dataset)
df.head()
df.to_excel('Feature_Engineering_Testing1.xlsx', index=False)
